# %%
import os
import librosa
import librosa.display
import IPython.display as ipd

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from itertools import cycle
from tqdm import tqdm
#sns.set_theme(style="white", palette=None)
#color_pal=plt.rcParams["axes.prop_cycle"].by_key()["color"]
#color_cycle=cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
audio_files=glob("C:/Users/User/EDD_audio/EATD-Corpus/*/*.wav")
#ipd.Audio(audio_files[0])
y, sr=librosa.load(audio_files[0]) #The raw output is y, sample rate is sr
#print(f'y:{y[:10]}')
#print(f'shape:{y.shape}')
#print(f'sr:{sr}')

#pd.Series(y).plot(figsize=(10,5), lw=1, title="Raw audio example")
y_trimmed, _= librosa.effects.trim(y, top_db=20)
#pd.Series(y_trimmed).plot(figsize=(10,5), lw=1, title="Raw audio trimmed example", color=color_pal[1])
pd.Series(y_trimmed[5000:10000]).plot(figsize=(10,5), lw=1, title="Raw audio zoomed in example")
# Out:
# <Axes: title={'center': 'Raw audio zoomed in example'}>

# %%
# Load audio file using librosa
def load_audio_file(file_path, duration=4, sr=22050):
    y, _ = librosa.load(file_path, sr=sr, duration=duration)
    return y, sr

def plot_waveform(y, sr, title="Waveform", save_path=None):
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr)
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Amplitude")
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()
    plt.close()

def plot_stft_spectro(y, sr, title="Spectrogram", save_path=None):
    plt.figure(figsize=(10, 4))
    spec = np.abs(librosa.stft(y))
    spec_db = librosa.amplitude_to_db(spec, ref=np.max)

    librosa.display.specshow(spec_db, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()
    plt.close()

# %%
#files_in_directory = os.listdir("EATD-Corpus")
#print(files_in_directory)
       
#audio_files = [os.path.join(data_path, f) for f in os.listdir(data_path) if f.lower().endswith('out.wav')]
audio_files = glob(os.path.join("EATD-Corpus/t_*", '**/*out.wav').replace('\\','/'), recursive=True)

for audio_file in audio_files:
    # Load audio file
    audio, sr = load_audio_file(audio_file)
    #print(f'loc:{audio_file}')
    # Generate waveform plot
    waveform_image_path = os.path.splitext(audio_file)[0] + '_waveform.png'
    spectro_image_path = os.path.splitext(audio_file)[0] + '_stft_spectro.png'
    print(spectro_image_path)
    plot_waveform(audio, sr, title="Waveform", save_path=waveform_image_path)
    plot_stft_spectro(audio, sr, title="Spectrogram", save_path=spectro_image_path)
# Out:
# ['.DS_Store', 't_1', 't_10', 't_101', 't_102', 't_103', 't_104', 't_105', 't_106', 't_107', 't_109', 't_11', 't_111', 't_12', 't_13', 't_14', 't_15', 't_16', 't_18', 't_2', 't_20', 't_21', 't_22', 't_26', 't_27', 't_28', 't_29', 't_3', 't_30', 't_31', 't_32', 't_33', 't_34', 't_35', 't_36', 't_38', 't_39', 't_40', 't_41', 't_42', 't_43', 't_44', 't_45', 't_46', 't_47', 't_48', 't_5', 't_51', 't_53', 't_54', 't_55', 't_56', 't_58', 't_59', 't_6', 't_60', 't_61', 't_62', 't_63', 't_64', 't_66', 't_67', 't_68', 't_69', 't_70', 't_75', 't_76', 't_78', 't_79', 't_8', 't_81', 't_82', 't_85', 't_86', 't_87', 't_88', 't_89', 't_9', 't_90', 't_91', 't_93', 't_96', 't_97', 't_99', 'v_10', 'v_103', 'v_104', 'v_105', 'v_106', 'v_11', 'v_12', 'v_13', 'v_15', 'v_16', 'v_17', 'v_18', 'v_19', 'v_2', 'v_20', 'v_21', 'v_22', 'v_23', 'v_24', 'v_25', 'v_27', 'v_28', 'v_29', 'v_30', 'v_31', 'v_32', 'v_36', 'v_37', 'v_39', 'v_4', 'v_41', 'v_42', 'v_43', 'v_45', 'v_47', 'v_48', 'v_49', 'v_5', 'v_51', 'v_52', 'v_53', 'v_55', 'v_56', 'v_57', 'v_58', 'v_61', 'v_62', 'v_63', 'v_64', 'v_65', 'v_66', 'v_67', 'v_69', 'v_7', 'v_70', 'v_71', 'v_72', 'v_73', 'v_74', 'v_75', 'v_76', 'v_77', 'v_79', 'v_8', 'v_81', 'v_82', 'v_83', 'v_84', 'v_86', 'v_87', 'v_88', 'v_89', 'v_9', 'v_90', 'v_94', 'v_96', 'v_97', 'v_98', 'v_99']
# EATD-Corpus\t_1\negative_out_stft_spectro.png
# EATD-Corpus\t_1\neutral_out_stft_spectro.png
# EATD-Corpus\t_1\positive_out_stft_spectro.png
# EATD-Corpus\t_10\negative_out_stft_spectro.png
# EATD-Corpus\t_10\neutral_out_stft_spectro.png
# EATD-Corpus\t_10\positive_out_stft_spectro.png
# EATD-Corpus\t_101\negative_out_stft_spectro.png
# EATD-Corpus\t_101\neutral_out_stft_spectro.png
# EATD-Corpus\t_101\positive_out_stft_spectro.png
# EATD-Corpus\t_102\negative_out_stft_spectro.png
# EATD-Corpus\t_102\neutral_out_stft_spectro.png
# EATD-Corpus\t_102\positive_out_stft_spectro.png
# EATD-Corpus\t_103\negative_out_stft_spectro.png
# EATD-Corpus\t_103\neutral_out_stft_spectro.png
# EATD-Corpus\t_103\positive_out_stft_spectro.png
# EATD-Corpus\t_104\negative_out_stft_spectro.png
# EATD-Corpus\t_104\neutral_out_stft_spectro.png
# EATD-Corpus\t_104\positive_out_stft_spectro.png
# EATD-Corpus\t_105\negative_out_stft_spectro.png
# EATD-Corpus\t_105\neutral_out_stft_spectro.png
# EATD-Corpus\t_105\positive_out_stft_spectro.png
# EATD-Corpus\t_106\negative_out_stft_spectro.png
# EATD-Corpus\t_106\neutral_out_stft_spectro.png
# EATD-Corpus\t_106\positive_out_stft_spectro.png
# EATD-Corpus\t_107\negative_out_stft_spectro.png
# EATD-Corpus\t_107\neutral_out_stft_spectro.png
# EATD-Corpus\t_107\positive_out_stft_spectro.png
# EATD-Corpus\t_109\negative_out_stft_spectro.png
# EATD-Corpus\t_109\neutral_out_stft_spectro.png
# EATD-Corpus\t_109\positive_out_stft_spectro.png
# EATD-Corpus\t_11\negative_out_stft_spectro.png
# EATD-Corpus\t_11\neutral_out_stft_spectro.png
# EATD-Corpus\t_11\positive_out_stft_spectro.png
# EATD-Corpus\t_111\negative_out_stft_spectro.png
# EATD-Corpus\t_111\neutral_out_stft_spectro.png
# EATD-Corpus\t_111\positive_out_stft_spectro.png
# EATD-Corpus\t_12\negative_out_stft_spectro.png
# EATD-Corpus\t_12\neutral_out_stft_spectro.png
# EATD-Corpus\t_12\positive_out_stft_spectro.png
# EATD-Corpus\t_13\negative_out_stft_spectro.png
# EATD-Corpus\t_13\neutral_out_stft_spectro.png
# EATD-Corpus\t_13\positive_out_stft_spectro.png
# EATD-Corpus\t_14\negative_out_stft_spectro.png
# EATD-Corpus\t_14\neutral_out_stft_spectro.png
# EATD-Corpus\t_14\positive_out_stft_spectro.png
# EATD-Corpus\t_15\negative_out_stft_spectro.png
# EATD-Corpus\t_15\neutral_out_stft_spectro.png
# EATD-Corpus\t_15\positive_out_stft_spectro.png
# EATD-Corpus\t_16\negative_out_stft_spectro.png
# EATD-Corpus\t_16\neutral_out_stft_spectro.png
# EATD-Corpus\t_16\positive_out_stft_spectro.png
# EATD-Corpus\t_18\negative_out_stft_spectro.png
# EATD-Corpus\t_18\neutral_out_stft_spectro.png
# EATD-Corpus\t_18\positive_out_stft_spectro.png
# EATD-Corpus\t_2\negative_out_stft_spectro.png
# EATD-Corpus\t_2\neutral_out_stft_spectro.png
# EATD-Corpus\t_2\positive_out_stft_spectro.png
# EATD-Corpus\t_20\negative_out_stft_spectro.png
# EATD-Corpus\t_20\neutral_out_stft_spectro.png
# EATD-Corpus\t_20\positive_out_stft_spectro.png
# EATD-Corpus\t_21\negative_out_stft_spectro.png
# EATD-Corpus\t_21\neutral_out_stft_spectro.png
# EATD-Corpus\t_21\positive_out_stft_spectro.png
# EATD-Corpus\t_22\negative_out_stft_spectro.png
# EATD-Corpus\t_22\neutral_out_stft_spectro.png
# EATD-Corpus\t_22\positive_out_stft_spectro.png
# EATD-Corpus\t_26\negative_out_stft_spectro.png
# EATD-Corpus\t_26\neutral_out_stft_spectro.png
# EATD-Corpus\t_26\positive_out_stft_spectro.png
# EATD-Corpus\t_27\negative_out_stft_spectro.png
# EATD-Corpus\t_27\neutral_out_stft_spectro.png
# EATD-Corpus\t_27\positive_out_stft_spectro.png
# EATD-Corpus\t_28\negative_out_stft_spectro.png
# EATD-Corpus\t_28\neutral_out_stft_spectro.png
# EATD-Corpus\t_28\positive_out_stft_spectro.png
# EATD-Corpus\t_29\negative_out_stft_spectro.png
# EATD-Corpus\t_29\neutral_out_stft_spectro.png
# EATD-Corpus\t_29\positive_out_stft_spectro.png
# EATD-Corpus\t_3\negative_out_stft_spectro.png
# EATD-Corpus\t_3\neutral_out_stft_spectro.png
# EATD-Corpus\t_3\positive_out_stft_spectro.png
# EATD-Corpus\t_30\negative_out_stft_spectro.png
# EATD-Corpus\t_30\neutral_out_stft_spectro.png
# EATD-Corpus\t_30\positive_out_stft_spectro.png
# EATD-Corpus\t_31\negative_out_stft_spectro.png
# EATD-Corpus\t_31\neutral_out_stft_spectro.png
# EATD-Corpus\t_31\positive_out_stft_spectro.png
# EATD-Corpus\t_32\negative_out_stft_spectro.png
# EATD-Corpus\t_32\neutral_out_stft_spectro.png
# EATD-Corpus\t_32\positive_out_stft_spectro.png
# EATD-Corpus\t_33\negative_out_stft_spectro.png
# EATD-Corpus\t_33\neutral_out_stft_spectro.png
# EATD-Corpus\t_33\positive_out_stft_spectro.png
# EATD-Corpus\t_34\negative_out_stft_spectro.png
# EATD-Corpus\t_34\neutral_out_stft_spectro.png
# EATD-Corpus\t_34\positive_out_stft_spectro.png
# EATD-Corpus\t_35\negative_out_stft_spectro.png
# EATD-Corpus\t_35\neutral_out_stft_spectro.png
# EATD-Corpus\t_35\positive_out_stft_spectro.png
# EATD-Corpus\t_36\negative_out_stft_spectro.png
# EATD-Corpus\t_36\neutral_out_stft_spectro.png
# EATD-Corpus\t_36\positive_out_stft_spectro.png
# EATD-Corpus\t_38\negative_out_stft_spectro.png
# EATD-Corpus\t_38\neutral_out_stft_spectro.png
# EATD-Corpus\t_38\positive_out_stft_spectro.png
# EATD-Corpus\t_39\negative_out_stft_spectro.png
# EATD-Corpus\t_39\neutral_out_stft_spectro.png
# EATD-Corpus\t_39\positive_out_stft_spectro.png
# EATD-Corpus\t_40\negative_out_stft_spectro.png
# EATD-Corpus\t_40\neutral_out_stft_spectro.png
# EATD-Corpus\t_40\positive_out_stft_spectro.png
# EATD-Corpus\t_41\negative_out_stft_spectro.png
# EATD-Corpus\t_41\neutral_out_stft_spectro.png
# EATD-Corpus\t_41\positive_out_stft_spectro.png
# EATD-Corpus\t_42\negative_out_stft_spectro.png
# EATD-Corpus\t_42\neutral_out_stft_spectro.png
# EATD-Corpus\t_42\positive_out_stft_spectro.png
# EATD-Corpus\t_43\negative_out_stft_spectro.png
# EATD-Corpus\t_43\neutral_out_stft_spectro.png
# EATD-Corpus\t_43\positive_out_stft_spectro.png
# EATD-Corpus\t_44\negative_out_stft_spectro.png
# EATD-Corpus\t_44\neutral_out_stft_spectro.png
# EATD-Corpus\t_44\positive_out_stft_spectro.png
# EATD-Corpus\t_45\negative_out_stft_spectro.png
# EATD-Corpus\t_45\neutral_out_stft_spectro.png
# EATD-Corpus\t_45\positive_out_stft_spectro.png
# EATD-Corpus\t_46\negative_out_stft_spectro.png
# EATD-Corpus\t_46\neutral_out_stft_spectro.png
# EATD-Corpus\t_46\positive_out_stft_spectro.png
# EATD-Corpus\t_47\negative_out_stft_spectro.png
# EATD-Corpus\t_47\neutral_out_stft_spectro.png
# EATD-Corpus\t_47\positive_out_stft_spectro.png
# EATD-Corpus\t_48\negative_out_stft_spectro.png
# EATD-Corpus\t_48\neutral_out_stft_spectro.png
# EATD-Corpus\t_48\positive_out_stft_spectro.png
# EATD-Corpus\t_5\negative_out_stft_spectro.png
# EATD-Corpus\t_5\neutral_out_stft_spectro.png
# EATD-Corpus\t_5\positive_out_stft_spectro.png
# EATD-Corpus\t_51\negative_out_stft_spectro.png
# EATD-Corpus\t_51\neutral_out_stft_spectro.png
# EATD-Corpus\t_51\positive_out_stft_spectro.png
# EATD-Corpus\t_53\negative_out_stft_spectro.png
# EATD-Corpus\t_53\neutral_out_stft_spectro.png
# EATD-Corpus\t_53\positive_out_stft_spectro.png
# EATD-Corpus\t_54\negative_out_stft_spectro.png
# EATD-Corpus\t_54\neutral_out_stft_spectro.png
# EATD-Corpus\t_54\positive_out_stft_spectro.png
# EATD-Corpus\t_55\negative_out_stft_spectro.png
# EATD-Corpus\t_55\neutral_out_stft_spectro.png
# EATD-Corpus\t_55\positive_out_stft_spectro.png
# EATD-Corpus\t_56\negative_out_stft_spectro.png
# EATD-Corpus\t_56\neutral_out_stft_spectro.png
# EATD-Corpus\t_56\positive_out_stft_spectro.png
# EATD-Corpus\t_58\negative_out_stft_spectro.png
# EATD-Corpus\t_58\neutral_out_stft_spectro.png
# EATD-Corpus\t_58\positive_out_stft_spectro.png
# EATD-Corpus\t_59\negative_out_stft_spectro.png
# EATD-Corpus\t_59\neutral_out_stft_spectro.png
# EATD-Corpus\t_59\positive_out_stft_spectro.png
# EATD-Corpus\t_6\negative_out_stft_spectro.png
# EATD-Corpus\t_6\neutral_out_stft_spectro.png
# EATD-Corpus\t_6\positive_out_stft_spectro.png
# EATD-Corpus\t_60\negative_out_stft_spectro.png
# EATD-Corpus\t_60\neutral_out_stft_spectro.png
# EATD-Corpus\t_60\positive_out_stft_spectro.png
# EATD-Corpus\t_61\negative_out_stft_spectro.png
# EATD-Corpus\t_61\neutral_out_stft_spectro.png
# EATD-Corpus\t_61\positive_out_stft_spectro.png
# EATD-Corpus\t_62\negative_out_stft_spectro.png
# EATD-Corpus\t_62\neutral_out_stft_spectro.png
# EATD-Corpus\t_62\positive_out_stft_spectro.png
# EATD-Corpus\t_63\negative_out_stft_spectro.png
# EATD-Corpus\t_63\neutral_out_stft_spectro.png
# EATD-Corpus\t_63\positive_out_stft_spectro.png
# EATD-Corpus\t_64\negative_out_stft_spectro.png
# EATD-Corpus\t_64\neutral_out_stft_spectro.png
# EATD-Corpus\t_64\positive_out_stft_spectro.png
# EATD-Corpus\t_66\negative_out_stft_spectro.png
# EATD-Corpus\t_66\neutral_out_stft_spectro.png
# EATD-Corpus\t_66\positive_out_stft_spectro.png
# EATD-Corpus\t_67\negative_out_stft_spectro.png
# EATD-Corpus\t_67\neutral_out_stft_spectro.png
# EATD-Corpus\t_67\positive_out_stft_spectro.png
# EATD-Corpus\t_68\negative_out_stft_spectro.png
# EATD-Corpus\t_68\neutral_out_stft_spectro.png
# EATD-Corpus\t_68\positive_out_stft_spectro.png
# EATD-Corpus\t_69\negative_out_stft_spectro.png
# EATD-Corpus\t_69\neutral_out_stft_spectro.png
# EATD-Corpus\t_69\positive_out_stft_spectro.png
# EATD-Corpus\t_70\negative_out_stft_spectro.png
# EATD-Corpus\t_70\neutral_out_stft_spectro.png
# EATD-Corpus\t_70\positive_out_stft_spectro.png
# EATD-Corpus\t_75\negative_out_stft_spectro.png
# EATD-Corpus\t_75\neutral_out_stft_spectro.png
# EATD-Corpus\t_75\positive_out_stft_spectro.png
# EATD-Corpus\t_76\negative_out_stft_spectro.png
# EATD-Corpus\t_76\neutral_out_stft_spectro.png
# EATD-Corpus\t_76\positive_out_stft_spectro.png
# EATD-Corpus\t_78\negative_out_stft_spectro.png
# EATD-Corpus\t_78\neutral_out_stft_spectro.png
# EATD-Corpus\t_78\positive_out_stft_spectro.png
# EATD-Corpus\t_79\negative_out_stft_spectro.png
# EATD-Corpus\t_79\neutral_out_stft_spectro.png
# EATD-Corpus\t_79\positive_out_stft_spectro.png
# EATD-Corpus\t_8\negative_out_stft_spectro.png
# EATD-Corpus\t_8\neutral_out_stft_spectro.png
# EATD-Corpus\t_8\positive_out_stft_spectro.png
# EATD-Corpus\t_81\negative_out_stft_spectro.png
# EATD-Corpus\t_81\neutral_out_stft_spectro.png
# EATD-Corpus\t_81\positive_out_stft_spectro.png
# EATD-Corpus\t_82\negative_out_stft_spectro.png
# EATD-Corpus\t_82\neutral_out_stft_spectro.png
# EATD-Corpus\t_82\positive_out_stft_spectro.png
# EATD-Corpus\t_85\negative_out_stft_spectro.png
# EATD-Corpus\t_85\neutral_out_stft_spectro.png
# EATD-Corpus\t_85\positive_out_stft_spectro.png
# EATD-Corpus\t_86\negative_out_stft_spectro.png
# EATD-Corpus\t_86\neutral_out_stft_spectro.png
# EATD-Corpus\t_86\positive_out_stft_spectro.png
# EATD-Corpus\t_87\negative_out_stft_spectro.png
# EATD-Corpus\t_87\neutral_out_stft_spectro.png
# EATD-Corpus\t_87\positive_out_stft_spectro.png
# EATD-Corpus\t_88\negative_out_stft_spectro.png
# EATD-Corpus\t_88\neutral_out_stft_spectro.png
# EATD-Corpus\t_88\positive_out_stft_spectro.png
# EATD-Corpus\t_89\negative_out_stft_spectro.png
# EATD-Corpus\t_89\neutral_out_stft_spectro.png
# EATD-Corpus\t_89\positive_out_stft_spectro.png
# EATD-Corpus\t_9\negative_out_stft_spectro.png
# EATD-Corpus\t_9\neutral_out_stft_spectro.png
# EATD-Corpus\t_9\positive_out_stft_spectro.png
# EATD-Corpus\t_90\negative_out_stft_spectro.png
# EATD-Corpus\t_90\neutral_out_stft_spectro.png
# EATD-Corpus\t_90\positive_out_stft_spectro.png
# EATD-Corpus\t_91\negative_out_stft_spectro.png
# EATD-Corpus\t_91\neutral_out_stft_spectro.png
# EATD-Corpus\t_91\positive_out_stft_spectro.png
# EATD-Corpus\t_93\negative_out_stft_spectro.png
# EATD-Corpus\t_93\neutral_out_stft_spectro.png
# EATD-Corpus\t_93\positive_out_stft_spectro.png
# EATD-Corpus\t_96\negative_out_stft_spectro.png
# EATD-Corpus\t_96\neutral_out_stft_spectro.png
# EATD-Corpus\t_96\positive_out_stft_spectro.png
# EATD-Corpus\t_97\negative_out_stft_spectro.png
# EATD-Corpus\t_97\neutral_out_stft_spectro.png
# EATD-Corpus\t_97\positive_out_stft_spectro.png
# EATD-Corpus\t_99\negative_out_stft_spectro.png
# EATD-Corpus\t_99\neutral_out_stft_spectro.png
# EATD-Corpus\t_99\positive_out_stft_spectro.png

# %%
# Function to extract features from audio files
def extract_features(file_path):
    try:
        # Load audio file
        audio_data, _ = librosa.load(file_path, res_type='kaiser_fast')
        print("audio loaded")
        # Extract features
        mfccs = np.mean(librosa.feature.mfcc(y=audio_data, sr=sr, n_mfcc=13), axis=1)
        chroma = np.mean(librosa.feature.chroma_stft(y=audio_data, sr=sr), axis=1)
        mel = np.mean(librosa.feature.melspectrogram(y=audio_data, sr=sr), axis=1)
        # Combine all features into one array
        print("features combined")
        return np.hstack((mfccs, chroma, mel))
    except Exception as e:
        print(f"Error encountered while processing {file_path}: {e}")
        return None
  
# Function to preprocess the entire dataset
def preprocess_dataset(dataset_path):
    data = []
    labels = []
    # Traverse through all files in the dataset directory
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith("out.wav"):
                file_path = os.path.join(root, file).replace('\\','/')
                # Extract features
                features = extract_features(file_path)
                print(f'features:{features}')
                if features is not None:
                    data.append(features)
                    print("features appended")
                # Extract label from the file path (assuming directory structure)
                    if file.startswith("positive"):
                        class_label='positive'
                    elif file.startswith("neutral"):
                        class_label='neutral'
